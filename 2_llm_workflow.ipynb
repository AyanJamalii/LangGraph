# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-3.5-flash")

# %%
# Create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f"Answers the following question {question}"

    # ask that ques to the llm
    answer = model.invoke(prompt).content

    # update the ans in state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)


# compile
workflow = graph.compile()

# %%
# Execute

initial_state = {'question': 'How far is the moon from the earth?'}
final_state = workflow.invoke(initial_state)
print(final_state['answer'])
# Out:
# [{'type': 'text', 'text': 'On average, the Moon is about **238,855 miles (384,400 kilometers)** away from Earth. \n\nHowever, because the Moon’s orbit around Earth is not a perfect circle but rather an oval (ellipse), this distance changes constantly. \n\nHere are the specific distances:\n*   **Closest approach (Perigee):** About **225,623 miles (363,300 km)**. When a full moon happens at this point, it is called a "supermoon" because it looks larger and brighter.\n*   **Farthest point (Apogee):** About **252,088 miles (405,500 km)**.\n\n### To put this distance into perspective:\n*   **Fitting Earths:** You could fit about **30 Earth-sized planets** in the space between the Earth and the Moon.\n*   **Speed of Light:** Light travels at 186,282 miles per second. It takes about **1.3 seconds** for light (or a radio signal) to travel from the Moon to the Earth.\n*   **Travel time:** \n    *   It took the **Apollo 11 astronauts** 3 days, 3 hours, and 49 minutes to reach lunar orbit.\n    *   If you could **drive a car** at a constant speed of 60 mph (96 km/h) to the Moon, it would take you about **166 days** of non-stop driving to get there.', 'extras': {'signature': '...'}}]
